# %% [markdown]
# ## HW5: Short report
#
# ### Takuya Ando

# %% [markdown]
# This report evaluates the performance of models in predicting projects with top 5 % highest risk of failing in fund raising. Below are the results which compare the performance of 7 models for each metric.
#
# For the evaluation of the models, at first I found out thresholds for each model which label projects of top 5 % highest risk as 1(failing get funds in 60 days), based on the distribution of predicted probability.
#
# Regarding accuracy, the models excluding SVM recorded around 70%, whereas the number of SVM is only 45%. SVM also shows low precision, although decision tree records low number here. Other models, such as logistic regression and bagging resulted in relatively high precision. However, for the recall and f1 , SVM had by far the highest score. On the other hand, all other models showed very low score for these metrics. For ap and auc, although there is no significant difference in the performance between 7 models, logistic regression performed relatively well.
#
# If you would like to deploy the machine learning model which detects projects of high risk, it depends the purpose of your intervention and availability of resource. That is, SVM records high recall score and low accuracy and precision score. That means SVM can pick up more projects which potentially has a risk of failing in funding, but it would also erroneously predict projects which actually does not have high risk of failing. On the other hand, other models such as logistic regression and bagging can detect projects with high risk more acculately, but they might miss more projects with potential risk than SVM.
#
# Overall, if you would like to pick up projects with risk of failing as many as possible and you have enough policy resource for the intervention, you can choose SVM. If your resource is limited and you want to focus on projects which truly has risk of failing, I recommend to deploy logistic regression or bagging.

# %%
import revmlpipeline
import analyzedata
# %load_ext autoreload
# %autoreload 2

# %%
analyzedata.compare_models()
